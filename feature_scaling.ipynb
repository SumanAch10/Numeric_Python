# %%
# take feature to a similar scale, better for adjusting weights, 
# Just because a feature is bigger doesn't mean that it is more important

# %% [markdown]
# Instead of:
# house size:  1200 - 2500
# bedrooms:    2 - 5
# age:         3 - 20
#
# After Scaling
# house size:  0 - 1
# bedrooms:    0 - 1
# age:         0 - 1
