# %%
import numpy as np

a = np.zeros(4)
a = np.zeros((4,))

print(a)

a = np.arange(4)
print(a)


X = np.array([[1],[2],[3],[4]])
print(f"X[1] has shape {X[1].shape}")
# Out:
# [0. 0. 0. 0.]
# [0 1 2 3]
# X[1] has shape (1,)
