# %%
import numpy as np

# Each row = one house
# Features: [size_sqft, num_bedrooms, age_years]
X_train = np.array([
    [1500, 3, 10],
    [2000, 4, 5],
    [1200, 2, 20],
    [1800, 3, 8],
    [2500, 5, 3]
])

# Actual prices (in $1000s)
y_train = np.array([300, 400, 200, 350, 500])

# Starting guesses
w_init = np.zeros(3)
b_init = 0.
alpha = 0.0001
iterations = 1000

# %%
def predict(x,w,b):
    y_predict = np.dot(x,w) + b
    return y_predict

y_predict = predict(X_train,w_init,b_init)
print(y_predict)
# Out:
# [0. 0. 0. 0. 0.]

# %%
def compute_cost(X,y_trian,w,b):
    cost = 0
    m = X.shape[0]
    for i in range(m):
        cost = cost + (np.dot(X[i],w)+b - y_train[i])**2
    cost = cost / (2 * m)
    return cost

cost = compute_cost(X_train,y_train,w_init,b_init)
print(cost)
# Out:
# 66250.0

# %%
def compute_gradient(X,y_train,w,b):
    m = X.shape[0]
    for i in range(m):
        cost = (np.dot(X[i],w)+b - y_train[i])**2

# %%
import sys

arr=list(map(int,input("Enter int elements: ").split()))
k=int(input("INTERVAL: "))

if len(arr)>10 or len(arr)==0:
    print ("Either nothing is typed or len exceded 10")
    sys.exit()
    

if (len(arr) < k):
    print("Array len is less than the subarr len")
    sys.exit()

new_arr=[]

index = len(arr)-k+1

max=0

if k==1:
   print (arr)

else:
    for x in range(index):
        compare=x
        for y in range(k-1):

            if arr[compare]>arr[compare+1]:
                max=arr[compare]
            elif  arr[compare]<arr[compare+1]:
                max=arr[compare+1]
            compare+=1
            
        new_arr.append(max)
            

    print(new_arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       3 arr=list(map(int,input("Enter int elements: ").split()))
# ----> 4 k=int(input("INTERVAL: "))
#       6 if len(arr)>10 or len(arr)==0:
#       7     print ("Either nothing is typed or len exceded 10")
#
# ValueError: invalid literal for int() with base 10: ''
